# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
# Define an empty list to fetch the weather data for each city
city_data = []
city_data
# Out:
# []

# %%
# print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# # LOOP
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units=metric&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
                                 
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | utrik
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | puerto natales
# Processing Record 5 of Set 1 | pacific grove
# Processing Record 6 of Set 1 | altai
# Processing Record 7 of Set 1 | vilyuysk
# Processing Record 8 of Set 1 | tucuma
# Processing Record 9 of Set 1 | alesund
# Processing Record 10 of Set 1 | kingston
# Processing Record 11 of Set 1 | brisas de zicatela
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | labuan
# Processing Record 15 of Set 1 | tazovsky
# Processing Record 16 of Set 1 | watsa
# Processing Record 17 of Set 1 | edinburgh of the seven seas
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | volosovo
# Processing Record 21 of Set 1 | planeta rica
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          bethel  41.3712  -73.4140     11.05        70           0
# 1           utrik  11.2278  169.8474     26.71        81          42
# 2    port lincoln -34.7333  135.8667     17.96        80          12
# 3  puerto natales -51.7236  -72.4875      5.11        84          73
# 4   pacific grove  36.6177 -121.9166     24.80        79           0
#
#    Wind Speed Country        Date
# 0        1.54      US  1682555038
# 1        9.06      MH  1682555136
# 2        8.69      AU  1682555137
# 3        2.51      CL  1682555137
# 4        2.24      US  1682555137

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                bethel  41.3712  -73.4140     11.05        70           0
# 1                 utrik  11.2278  169.8474     26.71        81          42
# 2          port lincoln -34.7333  135.8667     17.96        80          12
# 3        puerto natales -51.7236  -72.4875      5.11        84          73
# 4         pacific grove  36.6177 -121.9166     24.80        79           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      US  1682555038
# 1              9.06      MH  1682555136
# 2              8.69      AU  1682555137
# 3              2.51      CL  1682555137
# 4              2.24      US  1682555137

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
x_value = city_data_df["Lat"]
y_value = city_data_df["Max Temp"]
plt.scatter(x_value, y_value, marker="o", edgecolors="black")
# Incorporate the other graph properties
plt.title("City Max temperature vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_value = city_data_df["Lat"]
y_value = city_data_df["Humidity"]
plt.scatter(x_value, y_value, marker="o", edgecolors="black")
# Incorporate the other graph properties
plt.title("City Humidity vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_value = city_data_df["Lat"]
y_value = city_data_df["Cloudiness"]
plt.scatter(x_value, y_value, marker="o", edgecolors="black")
# Incorporate the other graph properties
plt.title("City Cloudiness vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_value = city_data_df["Lat"]
y_value = city_data_df["Wind Speed"]
plt.scatter(x_value, y_value, marker="o", edgecolors="black")
# Incorporate the other graph properties
plt.title("City Cloudiness vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def LinearRegression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    print(f'rvalue is {rvalue}')
    line_eq =f"y = {round(slope,2)}x+{round(intercept,2)}"
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               bethel  41.3712  -73.4140     11.05        70           0
# 1                utrik  11.2278  169.8474     26.71        81          42
# 4        pacific grove  36.6177 -121.9166     24.80        79           0
# 5                altai  46.3722   96.2583     -6.42        67          95
# 6             vilyuysk  63.7553  121.6247      0.02        89          95
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      US  1682555038
# 1              9.06      MH  1682555136
# 4              2.24      US  1682555137
# 5              5.26      MN  1682555137
# 6              3.99      RU  1682555138

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df =city_data_df.loc[city_data_df['Lat']<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                       port lincoln -34.7333  135.8667     17.96        80
# 3                     puerto natales -51.7236  -72.4875      5.11        84
# 7                             tucuma  -0.1833  -50.0500     24.91        89
# 12                           ushuaia -54.8000  -68.3000      4.81        87
# 16       edinburgh of the seven seas -37.0676  -12.3116     16.19        73
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                12        8.69      AU  1682555137
# 3                73        2.51      CL  1682555137
# 7                52        2.05      BR  1682555138
# 12                0        5.14      AR  1682555139
# 16               93       11.80      SH  1682555140

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df["Max Temp"]

LinearRegression(x_value, y_value)
result = LinearRegression(x_value, y_value)
plt.annotate(result,(0,0),fontsize=15,color="red")
plt.title("Northern Hemi City Max Temperature vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
# Out:
# rvalue is -0.8906747327609056
# rvalue is -0.8906747327609056
# Text(0, 0.5, 'Max Temperature(C)')

# %%
# Linear regression on Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df["Max Temp"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(-20,0),fontsize=15,color="red")
plt.title("Southern Hemi City Max Temperature vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
# Out:
# rvalue is 0.7587530630970226
# rvalue is 0.7587530630970226
# Text(0, 0.5, 'Max Temperature(C)')

# %% [markdown]
# **Discussion about the linear relationship:** In Northern or Southern hemispheres, as long as latitude closer to 0, the temperature will be higher.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df["Humidity"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(50,20),fontsize=15,color="red")
plt.title("Northern Hemi City Humidity vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# rvalue is 0.08941029745812293
# rvalue is 0.08941029745812293
# Text(0, 0.5, 'Humidity')

# %%
# Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df["Humidity"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(-50,30),fontsize=15,color="red")
plt.title("Southern Hemi City Humidity vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# rvalue is 0.15811410326477945
# rvalue is 0.15811410326477945
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# **Discussion about the linear relationship:** The correlations between humidity and latitude is weak.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df["Cloudiness"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(50,20),fontsize=15,color="red")
plt.title("Northern Hemi City Cloudiness vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# rvalue is 0.11553899448163
# rvalue is 0.11553899448163
# Text(0, 0.5, 'Cloudiness')

# %%
# Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df["Cloudiness"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(50,20),fontsize=15,color="red")
plt.title("Southern Hemi City Cloudiness vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# rvalue is 0.18792253048965282
# rvalue is 0.18792253048965282
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# **Discussion about the linear relationship:** The correlations between cloadiness and latitude is weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df["Wind Speed"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(0,10),fontsize=15,color="red")
plt.title("Northern Hemi City Wind Speed vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# rvalue is -0.03376748531199
# rvalue is -0.03376748531199
# Text(0, 0.5, 'Wind Speed')

# %%
# Southern Hemisphere
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df["Wind Speed"]

LinearRegression(x_value, y_value)
plt.annotate((LinearRegression(x_value,y_value)),(-20,10),fontsize=15,color="red")
plt.title("Southern Hemi City Wind Speed vs Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# rvalue is -0.2354176642377909
# rvalue is -0.2354176642377909
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# **Discussion about the linear relationship:** The correlations between wind speed and latitude in northern hemisphere cities is weak.  The correlations between wind speed and latitude in southern hemisphere cities is moderate. Wind speed decrease a little while latitude decrease.
